# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера V.3</h3>
#
# Удачи в следующих спринтах 👍
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера V.2</h3>
#
# Спасибо, что поправил, я оставил комментарии, если есть какие-то вопросы, то можешь задать. Если нет, то просто зашли работу обратно и я приму :)
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
# <h3>Комментарий студента</h3>
# Спасибо большое! Вопросов нет.
# </div>

# %% [markdown]
# # <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Привет! Меня зовут Алексей Тюрин, я буду делать ревью твоей работы. Давай будем общаться на «ты».
#
# У тебя хорошая, аккуратная работа 👍. **Можно** перед заменой пропусков показать их случайность, **нужно** чуть получше разбить на уровни по доходам и **можно** под другим углом посмотреть на проценты должников. Как со всем разберешься -- буду рад принять работу, удачи :)
#
# ---
# Комментарии делятся на 3 группы:
#
# Зелёным цветом отмечены комментарии, либо подчёркиваюищие удачные решения, либо содержащие какую-то дополнительную информацию или советы, они формально не требуют правки, но правки приветствуются. Выделены они так:
#
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера</h3>
#
# Тут текст
# </div>
#
# Жёлтым цветом выделены правки, которые желательны:
#
# <div class="alert alert-warning">
# <h3>❗ Комментарий реьюера</h3>
#
# Тут текст
# </div>
#
# Красным выделены правки, которые обязательны
#
# <div class="alert alert-danger">
# <h3>❌Комментарий реьюера</h3>
#
# Тут текст
# </div>
#
# Давай работать над проектом в диалоге: если ты **что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее». Если оставляешь комментарии на какой-то итерации ревью, пиши что-то вроде `комментарий студента V.номер итерации`
# </div>
#
# Цвет можно сделать, например, так
#
# <div class = "alert alert-info" >
# <h3>Комментарий студента</h3>
# Ревьюер душнила :)
# </div>
#
# Или так:
#
# <div class="alert alert-info" style="background:#ffdbf1;color:#2e00ab">
# <h3>Комментарий студента </h3>
#     ...
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
# <h3>Комментарий студента</h3>
# Здравствуйте! Спасибо за комментарии и полезные советы :)
# </div>

# %% [markdown]
# # Исследование надёжности заёмщиков
#
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели **кредитного скоринга** — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию

# %%
import pandas as pd

df = pd.read_csv('/datasets/data.csv')
display(df.head(5))


# Для демонстрации

df_copy = df.copy()
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       19351 non-null float64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        19351 non-null float64
# purpose             21525 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %%
display(df['children'].value_counts())
print('------------------------')
display(df['dob_years'].value_counts())
print('------------------------')
display(df['education'].value_counts())
print('------------------------')
display(df['education_id'].value_counts())
print('------------------------')
display(df['family_status'].value_counts())
print('------------------------')
display(df['family_status_id'].value_counts())
print('------------------------')
display(df['gender'].value_counts())
print('------------------------')
display(df['income_type'].value_counts())
print('------------------------')
display(df['debt'].value_counts())
print('------------------------')
display(df['purpose'].value_counts())
# Out:
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64
# ------------------------
# 35    617
# 40    609
# 41    607
# 34    603
# 38    598
# 42    597
# 33    581
# 39    573
# 31    560
# 36    555
# 44    547
# 29    545
# 30    540
# 48    538
# 37    537
# 50    514
# 43    513
# 32    510
# 49    508
# 28    503
# 45    497
# 27    493
# 56    487
# 52    484
# 47    480
# 54    479
# 46    475
# 58    461
# 57    460
# 53    459
# 51    448
# 59    444
# 55    443
# 26    408
# 60    377
# 25    357
# 61    355
# 62    352
# 63    269
# 64    265
# 24    264
# 23    254
# 65    194
# 66    183
# 22    183
# 67    167
# 21    111
# 0     101
# 68     99
# 69     85
# 70     65
# 71     58
# 20     51
# 72     33
# 19     14
# 73      8
# 74      6
# 75      1
# Name: dob_years, dtype: int64
# ------------------------
# среднее                13750
# высшее                  4718
# ...

# %%
print(df.groupby('education_id')['education'].unique())
# Out:
# education_id
# 0                             [высшее, ВЫСШЕЕ, Высшее]
# 1                          [среднее, Среднее, СРЕДНЕЕ]
# 2    [неоконченное высшее, НЕОКОНЧЕННОЕ ВЫСШЕЕ, Нео...
# 3                    [начальное, НАЧАЛЬНОЕ, Начальное]
# 4     [Ученая степень, УЧЕНАЯ СТЕПЕНЬ, ученая степень]
# Name: education, dtype: object

# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера</h3>
#
# Хороший способ 👍
# </div>

# %% [markdown]
# **Вывод**
#
#     Исходя из полученной информации, можно сказать, что данные плохие. В столбце "children" есть 2 артефакта - значение -1 и 20 не соответствуют действительности, то есть не может быть -1 ребенок, а значение 20 довольно подозрительное.
#     В столбце "dob_years", что соответствует возрасту клиента в годах, мы видим значение 0, что не соответствует действительности.
#     В столбце "education" есть много дубликатов.
#     В столбце "gender" есть один артефакт - значение XNA, что является ошибкой.
#     В столбце "purpose" также есть много неявных дубликатов.
#     Остальные столбцы вполне нормальные.
#     Данные артефакты, дубликаты могут возникнуть по разным причинам. Это может быть из-за человеческого фактора, а также из-за технологического.

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# <div class = "alert alert-info" >
# <h3>Комментарий студента</h3>
# Если я хочу переделать код по вашим комментариям, мне нужно удалять неправильный код или его просто закомментировать и ниже написать правильный?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера V.2</h3>
#
# С точки зрения процесса ревью наверное лучше комментировать, чтобы видеть разницу между тем, что было и что стало
# </div>

# %%
import numpy as np

print('Количество пропусков в столбце days_employed', len(df[df['days_employed'].isna()]))
print('Количество пропусков в столбце total_income', len(df[df['total_income'].isna()]))
print('---')
total_income_mean = df.groupby('income_type')['total_income'].mean()
total_income_median = df.groupby('income_type')['total_income'].median()
print('Средние значения', total_income_mean)
print('---')
print('Медиана', total_income_median)

#Заполнение пропусков в столбце "total_income" значением медианы
def insert_values_for_income_type(row):
    
    types = row['income_type']
    income = row['total_income']
    
    if types == 'сотрудник':
        if np.isnan(income) == True:
            return total_income_median[6]
        else:
            return income
        
    if types == 'компаньон':
        if np.isnan(income) == True:
            return total_income_median[3]
        else:
            return income
    
    if types == 'пенсионер':
        if np.isnan(income) == True:
            return total_income_median[4]
        else:
            return income
    
    if types == 'госслужащий':
        if np.isnan(income) == True:
            return total_income_median[2]
        else:
            return income
        
    if types == 'предприниматель':
        if np.isnan(income) == True:
            return total_income_median[5]
        else:
            return income
        
    if types == 'безработный':
        if np.isnan(income) == True:
            return total_income_median[0]
        else:
            return income
        
    if types == 'студент':
        if np.isnan(income) == True:
            return total_income_median[7]
        else:
            return income
        
    if types == 'в декрете':
        if np.isnan(income) == True:
            return total_income_median[1]
        else:
            return income    
        
df['total_income'] = df.apply(insert_values_for_income_type, axis = 1)
display(df.head(15))
# Out:
# Количество пропусков в столбце days_employed 2174
# Количество пропусков в столбце total_income 2174
# ---
# Средние значения income_type
# безработный        131339.751676
# в декрете           53829.130729
# госслужащий        170898.309923
# компаньон          202417.461462
# пенсионер          137127.465690
# предприниматель    499163.144947
# сотрудник          161380.260488
# студент             98201.625314
# Name: total_income, dtype: float64
# ---
# Медиана income_type
# безработный        131339.751676
# в декрете           53829.130729
# госслужащий        150447.935283
# компаньон          172357.950966
# пенсионер          118514.486412
# предприниматель    499163.144947
# сотрудник          142594.396847
# студент             98201.625314
# Name: total_income, dtype: float64
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <h3>❗ Комментарий реьюера</h3>
#
# Ты на самом деле очень аккуратно заполняешь пропуски. Я отмечу в этом комментарии один важный момент, на который надо обращать внимание. Пропуски таким образом можно заменять, толькое если они случайны, т.е. не зависят от наблюдаемых значений в других столбцах, что если бы все прпоуски в столбце `total_income` были только у людей без образования, а у тех людей без образования, где пропусков нет, доход указан 0? Тогда надо было бы заменить пропуски на 0.
#
# Чтобы проверить, что пропуски случайны, нужно показать, как я уже выше сказал, что они не зависят от наблюдаемых значений в других столбцах, для этого для каждого столбца надо посмотреть на распределение значений для среза с прпоускамми и сравнить его для такого же распределения для среза без пропусков. Если они совпадают, то пропуски от этого столбца не зависят. Если пропуски не зависят ни от одного столбца, то они случайны. Проще всего тут это увидеть, если сделать `value_counts(normalize=True)` для столбца `incomer_type` для строк с пропусками в `total_income` и без пропусков и сравнить полученные распределения. Это я и предлагаю сделать. Подробнее о типах пропусков можно почитать тут: https://loginom.ru/blog/missing
#
# Также с точки зрения кода написано не совсем удобно, что если бы число уникальных профессий было 20? Или оно бы поменялось? Пришлось бы переписывать код, такую замену проще всего сделать через `groupby` + `transform` + `fillna`
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
# <h3>Комментарий студента</h3>
# Насчет замены. Можно ли это сделать так? :
#
#     total_income_median = df.groupby('income_type')['total_income'].median()
#     def insert_values_for_income_type(row):
#
#     types = row['income_type']
#     income = row['total_income']
#     if np.isnan(income) == True:
#         return df.groupby('income_type')['total_income'].transform('median').fillna(total_income_median)
#     else:
#         return income
#
#     df['total_income'] = df.apply(insert_values_for_income_type, axis = 1)
#     display(df.head(15))
#
# Этот момент мне не очень понятен, т.к сделал интуитивно.
#
#     if np.isnan(income) == True:
#         return df.groupby('income_type')['total_income'].transform('median').fillna(total_income_median)
#     else:
#         return income
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера V.2</h3>
#
# То, что выше работать не будет, потому что ты для каждой строки возврашаешь серию. Такой `transform` берёт каждую группу и применяет к ней функцию, т.е. выше он в каждой группе  меняет все значения на медиану по группе, а затем ты заменяешь пропуски, но пропусков больше нет, при это такой `fillna` заменяет по индексам, если передавать туда серию, а у тебя серии имеют разные индексы.
#
#
# Тут достаточно сделать `df['total_income'] = df.groupby('income_type')['total_income'].transform(lambda group : group.fillna(group.median()))`
#
# Т.е. не нужно ни функции, ни `apply`
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
# <h3>Комментарий студента</h3>
# Если честно, не совсем понял как проверить, что пропуски случайны. Применил value_counts(normalize=True) для столбца income_type и total_income. Тут, как я понимаю, частота уникальных значений, но как мне это поможет?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера V.2</h3>
#
# Чтобы показать, что пропуски не зависят от столбца `income_type`, нужно взять два среза для `income_type`: для строк с пропусками в `total_income` и без и сравнить распределения:
# </div>

# %%
# Код ревьюера

display(df_copy[df_copy['total_income'].isna()]['income_type'].value_counts(normalize=True))
display(df_copy[df_copy['total_income'].notna()]['income_type'].value_counts(normalize=True))
# Out:
# сотрудник          0.508280
# компаньон          0.233671
# пенсионер          0.189972
# госслужащий        0.067617
# предприниматель    0.000460
# Name: income_type, dtype: float64
# сотрудник          0.517493
# компаньон          0.236525
# пенсионер          0.177924
# госслужащий        0.067800
# безработный        0.000103
# предприниматель    0.000052
# в декрете          0.000052
# студент            0.000052
# Name: income_type, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера V.2</h3>
#
# Выше видно, что распределения совпадают, значит пропуски от столбца `income_type` не зависят. Аналогично и для других столбцов можно показать
# </div>

# %%
print(df['income_type'].value_counts(normalize=True))
print('---')
print(df['total_income'].value_counts(normalize=True))
# Out:
# сотрудник          0.516562
# компаньон          0.236237
# пенсионер          0.179141
# госслужащий        0.067782
# предприниматель    0.000093
# безработный        0.000093
# в декрете          0.000046
# студент            0.000046
# Name: income_type, dtype: float64
# ---
# 142594.396847    0.051336
# 172357.950966    0.023647
# 118514.486412    0.019233
# 150447.935283    0.006829
# 499163.144947    0.000093
#                    ...
# 133299.194693    0.000046
# 115080.782380    0.000046
# 84896.781597     0.000046
# 153838.839212    0.000046
# 150014.128510    0.000046
# Name: total_income, Length: 19353, dtype: float64

# %%
#Убираю значение 0 в столбце dob_years, XNA в столбце gender и значения -1 и 20 в столбце children
df = df[(df['dob_years'] != 0) & (df['gender'] != 'XNA') & (df['children'] != -1) & (df['children'] != 20)]
display(df['dob_years'].value_counts())
display(df['gender'].value_counts())
display(df['children'].value_counts())
display(df.head(10))
# Out:
# 35    614
# 40    603
# 41    603
# 34    597
# 38    595
# 42    592
# 33    577
# 39    572
# 31    556
# 36    553
# 29    543
# 44    543
# 30    536
# 48    536
# 37    531
# 43    510
# 50    509
# 32    506
# 49    505
# 28    501
# 45    494
# 27    490
# 52    483
# 56    482
# 47    480
# 54    476
# 46    469
# 58    461
# 53    457
# 57    457
# 51    446
# 55    441
# 59    441
# 26    406
# 60    376
# 25    356
# 61    353
# 62    351
# 63    268
# 64    263
# 24    262
# 23    252
# 65    194
# 66    183
# 22    183
# 67    167
# 21    110
# 68     99
# 69     83
# 70     65
# 71     58
# 20     51
# 72     33
# 19     14
# 73      8
# 74      6
# 75      1
# Name: dob_years, dtype: int64
# F    14083
# M     7218
# Name: gender, dtype: int64
# 0    14079
# 1     4802
# 2     2042
# 3      328
# 4       41
# 5        9
# Name: children, dtype: int64
#    children  days_employed  dob_years education  education_id  \
# ...

# %% [markdown]
# **Вывод**
#
#     Пропуски в столбце total_income были заполнены значениемя медианы, так как может быть ситуация, когда сотрудник может получать слишком большую зарплату, что скажется на среднем.

# %% [markdown]
# ### Замена типа данных

# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера</h3>
#
# Можно просто `df['days_employed'].abs()`. Отрицательные значения могли появится, если, например, из меньшей даты вычитают большую. Ещё можно заметить, что изначально положительные значения слишком большия для числа дней
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
# <h3>Комментарий студента</h3>
# Да, я заметил, что некоторые значения слишком большие. Возможно ли, что это просто артефакты? Если да, то получается надо избавиться от таких строк, где есть такие значения?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера V.2</h3>
#
# Этот столбец нам не нужен, поэтому с ним можно ничего не делать. Но тут сходу тяжело определить почему такие аномально большие значения получились, тем более их довольно много
# </div>

# %%
# в столбце days_employed отрицательные значения,поэтому нужны модули этих значений
def convert_to_modul(row):
    return abs(row)

df['days_employed'] = df['days_employed'].apply(convert_to_modul)

display(df.head(5))
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   Среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# ...

# %%
df = df.astype({'total_income': int})
display(df.head(5))
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   Среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# ...

# %% [markdown]
# **Вывод**
#
#     Привели к типу int столбец "total_income"

# %% [markdown]
# ### Обработка дубликатов

# %%
# Все значения в столбце education, family_status, income_type привел к нижнему регистру и после этого удалил дубликаты 
# и посчитал их
df['education'] = df['education'].str.lower()
df['family_status'] = df['family_status'].str.lower()
df['income_type'] = df['income_type'].str.lower()
df['purpose'] = df['purpose'].str.lower()
df = df.drop_duplicates()
display(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Лемматизация

# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера</h3>
#
# Можно лемматизацию соединить вместе с функцией `goal`, потому что отдельно она особо не нужна, а так -- всё верно. А как ты определяешь цели? Просто посморев выше на `value_counts`?
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
# <h3>Комментарий студента</h3>
# Да, с помощью value_counts я увидел, что все цели можно разбить на 4 группы: недвижимость, автомобиль, образование, свадьба. Я понимаю, что в реальности цели могут быть по разному написаны очень много раз, может быть и 100 разных целей и т.д, и в таком случае мой мой способ будет неправильный. Не подскажите, как в таком случае лучше сделать?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера V.2</h3>
#
# В общем случае для этого есть алгоритмы кластеризации, которые на самом деле сами всё разобьют. Что-то что можно руками попробовать сделать не зная о таких алгоритмах, это лемматизировать изначальные цели и убрать из них лишние слова типа пробелов, союзов, местоимений и т.п. и выделять уже из очищенных целей визуально
# </div>

# %%
from pymystem3 import Mystem
m = Mystem()

def lemmas(row):
    lemmas = m.lemmatize(row)
    return lemmas
df['lemmas'] = df['purpose'].apply(lemmas)
display(df.head(5))
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose                                lemmas
# ...

# %%
def goal(row):
    if 'жилье' in row:
        return 'недвижимость'
    if 'недвижимость' in row:
        return 'недвижимость'
    if 'автомобиль' in row:
        return 'автомобиль'
    if 'образование' in row:
        return 'образование'
    if 'свадьба' in row:
        return 'свадьба'
df['goal'] = df['lemmas'].apply(goal)
display(df.head(5))
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose                                lemmas  \
# ...

# %% [markdown]
# **Вывод**
#
#    С помощью лемматизации в столбце goal теперь есть общие цели

# %% [markdown]
# ### Категоризация данных

# %%
# категория в зависимости от дохода. Все, что ниже медианы - Доход ниже среднего, выше - Доход выше среднего
#mediana = df['total_income'].median()

#def income(row):
    #if row > mediana:
        #return 'Доход выше среднего'
    #if row < mediana:
        #return 'Доход ниже среднего'
#df['income_category'] = df['total_income'].apply(income)
#display(df.head(5))

# %% [markdown]
# <div class = "alert alert-info" >
# <h3>Комментарий студента</h3>
# Ниже использовал qcut.
# </div>

# %%
df['income_category'] = pd.qcut(df['total_income'], q = 3, labels = ['Низкий доход','Средний доход','Высокий доход'])
df['range of values'] = pd.qcut(df['total_income'], q = 3)
display(df.head(5))
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1    8437.673028         42    высшее             0
# 1         1    4024.803754         36   среднее             1
# 2         0    5623.422610         33   среднее             1
# 3         3    4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose                                lemmas  \
# ...

# %% [markdown]
# **Вывод**
#
#     В зависимости от дохода можно категоризировать данные по столбцу total_income. Все, что ниже медианного значения - это
#     доход ниже среднего, а если выше - доход выше среднего.

# %% [markdown]
# <div class="alert alert-danger">
# <h3>❌Комментарий реьюера</h3>
#
# Хоть ты и используешь медиану, это всё равно не очень хорошая категоризация, потому что внутри групп дисперсия различается на порядок, группы же должны быть как можно более однородны. При разбиении на уровни по доходу обычно выделяют хотя бы 3 категории, условно `низкий`, `средний` и `высокий`. Чтобы получать группы предсказуемых размеров, можно разбивать по квантилям: https://forecasting.svetunkov.ru/etextbook/forecasting_toolbox/data-analysis-stat/ для этого есть `qcut`: https://pandas.pydata.org/docs/reference/api/pandas.qcut.html
# </div>

# %% [markdown]
# <div class = "alert alert-info" >
# <h3>Комментарий студента</h3>
# Спасибо за совет. Оказалось очень просто и полезно))
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера V.2</h3>
#
# 👍
# </div>

# %%
# Код ревьюера
df.groupby('income_category')['total_income'].std()
# Out:
# income_category
# Низкий доход      21559.981130
# Средний доход     15037.224006
# Высокий доход    114910.015731
# Name: total_income, dtype: float64

# %% [markdown]
# ## Шаг 3. Ответьте на вопросы

# %% [markdown]
# - Есть ли зависимость между наличием детей и возвратом кредита в срок?

# %%
df_children = df.pivot_table(index = 'children', columns = 'debt', values = 'days_employed', aggfunc = 'count')
df_children['процент'] = (df_children[0] / (df_children[0] + df_children[1])) * 100
display(df_children)
# Out:
# debt            0      1    процент
# children
# 0         11701.0  947.0  92.512650
# 1          3923.0  405.0  90.642329
# 2          1661.0  177.0  90.369967
# 3           271.0   22.0  92.491468
# 4            31.0    3.0  91.176471
# 5             8.0    NaN        NaN

# %% [markdown]
# **Вывод**
#
#     В принципе, зависимости между наличием детей и возвратом кредита в срок нет. Процент выдачи кредита в срок примерно одинаков.

# %% [markdown]
# <div class="alert alert-success">
# <h3>✔ Комментарий реьюера</h3>
#
# На самом деле разница даже в 2% может быть значимой. Более того, можно посмотреть на общий процент должников во всей выборке и сравнить прцоент в каждой группе с ним, чтобы понимать, насколько каждая группа рисковая. На практике проверяют статистическую значимость такой разницы долей, этому научат в следующих спринтах. Чтобы лучше увидеть влияние таких небольших процентов, можно посмотреть на процент должников, пересекая самые ненадежные группы для каждого параметра, т.е. посмотреть на процент в группе с 2 детьми, кто при этом не женат, имеет низкий доход и взял кредит на образование
# </div>

# %% [markdown]
# - Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
df_family = df.pivot_table(index = 'family_status', columns = 'debt', values = 'days_employed', aggfunc = 'count')
df_family['процент'] = (df_family[0] / (df_family[0] + df_family[1])) * 100
display(df_family)
# Out:
# debt                       0    1    процент
# family_status
# в разводе                994   75  92.984097
# вдовец / вдова           799   55  93.559719
# гражданский брак        3366  334  90.972973
# женат / замужем        10188  838  92.399782
# не женат / не замужем   2248  252  89.920000

# %% [markdown]
# **Вывод**
#
#     Здесь аналогичная ситуация. Процент выдачи кредита в срок примерно одинаков. Следовательно, зависимости между семейным положением и возвратом кредита в срок нет.

# %% [markdown]
# - Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
df_income = df.pivot_table(index = 'income_category', columns = 'debt', values = 'days_employed', aggfunc = 'count')
df_income['процент'] = (df_income[0] / (df_income[0] + df_income[1])) * 100
display(df_income)
# Out:
# debt                0    1    процент
# income_category
# Низкий доход     6155  542  91.906824
# Средний доход    5017  489  91.118780
# Высокий доход    6423  523  92.470487

# %% [markdown]
# **Вывод**
#
#     Также, как и в других ситуациях. Зависимости между уровнем дохода и возвратом кредита в срок нет.

# %% [markdown]
# - Как разные цели кредита влияют на его возврат в срок?

# %%
df_goal = df.pivot_table(index = 'goal', columns = 'debt', values = 'days_employed', aggfunc = 'count')
df_goal['процент'] = (df_goal[0] / (df_goal[0] + df_goal[1])) * 100
display(df_goal)
# Out:
# debt             0    1    процент
# goal
# автомобиль    3490  361  90.625811
# недвижимость  8954  710  92.653146
# образование   3227  330  90.722519
# свадьба       1924  153  92.633606

# %% [markdown]
# **Вывод**
#
#     Цели кредита не влияют на его возврат в срок.

# %% [markdown]
# ## Шаг 4. Общий вывод

# %% [markdown]
# Данный проект был разделен на несколько этапов.
# Первый этап - изучение общей информации. Данные были не пригодны для анализа, потому что было много артефактов, дубликатов и пропусков.
# На втором этапе все недостатки информации были устранены. Заполнил пропуски медианным значением в зависимости от типа занятости. Также были устранены дубликаты и артефакты. С помощью лемматизации сделал общие цели. Также в зависимости от дохода была проведена категоризация данных.
# В заключительном этапе был проведен анализ. Ответил на вопросы: 1) Есть ли зависимость между наличием детей и возвратом кредита в срок?; 2) Есть ли зависимость между семейным положением и возвратом кредита в срок?; 3) Как разные цели кредита влияют на его возврат в срок?; 4) Есть ли зависимость между уровнем дохода и возвратом кредита в срок?
# Как оказалось, зависимости нигде нет.

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл;
# - [ ]  файл изучен;
# - [ ]  определены пропущенные значения;
# - [ ]  заполнены пропущенные значения;
# - [ ]  есть пояснение, какие пропущенные значения обнаружены;
# - [ ]  описаны возможные причины появления пропусков в данных;
# - [ ]  объяснено, по какому принципу заполнены пропуски;
# - [ ]  заменен вещественный тип данных на целочисленный;
# - [ ]  есть пояснение, какой метод используется для изменения типа данных и почему;
# - [ ]  удалены дубликаты;
# - [ ]  есть пояснение, какой метод используется для поиска и удаления дубликатов;
# - [ ]  описаны возможные причины появления дубликатов в данных;
# - [ ]  выделены леммы в значениях столбца с целями получения кредита;
# - [ ]  описан процесс лемматизации;
# - [ ]  данные категоризированы;
# - [ ]  есть объяснение принципа категоризации данных;
# - [ ]  есть ответ на вопрос: "Есть ли зависимость между наличием детей и возвратом кредита в срок?";
# - [ ]  есть ответ на вопрос: "Есть ли зависимость между семейным положением и возвратом кредита в срок?";
# - [ ]  есть ответ на вопрос: "Есть ли зависимость между уровнем дохода и возвратом кредита в срок?";
# - [ ]  есть ответ на вопрос: "Как разные цели кредита влияют на его возврат в срок?";
# - [ ]  в каждом этапе есть выводы;
# - [ ]  есть общий вывод.
